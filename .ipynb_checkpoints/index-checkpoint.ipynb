# %%
# !pip install pandas
import pandas as pd
linkGit="https://github.com/IntroDeDatosEspaciales/prueba2/raw/main/raeePeru.csv"       #paste link here!

dataRaee=pd.read_csv(linkGit)
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/b7/f8/32d6b5aa4c4bc045fa2c4c58f88c325facc54721956c6313f0afea8ea853/pandas-2.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy>=1.23.2 from https://files.pythonhosted.org/packages/72/b2/02770e60c4e2f7e158d923ab0dea4e9f146a2dbf267fec6d8dc61d475689/numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      --- --------------------------------- 30.7/341.8 kB 640.0 kB/s eta 0:00:01
#      ------------- ------------------------ 122.9/341.8 kB 1.8 MB/s eta 0:00:01
#      ---------------------------- --------- 256.0/341.8 kB 2.2 MB/s eta 0:00:01
#      ----------------------------------- -- 317.4/341.8 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------  337.9/341.8 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 341.8/341.8 kB 1.4 MB/s eta 0:00:00
# ...

# %%
dataRaee
# Out:
#      Unnamed: 0 Departamento    Provincia     Distrito  \
# 0             0     Amazonas  Chachapoyas  Chachapoyas
# 1             1       Ancash       Huaraz       Huaraz
# 2             2       Ancash        Santa     Chimbote
# 3             3       Ancash        Santa     Chimbote
# 4             4       Ancash        Santa     Chimbote
# ..          ...          ...          ...          ...
# 152         152         Puno    San Roman      Juliaca
# 153         153   San Martín   San Martin     Tarapoto
# 154         154        Tacna        Tacna        Tacna
# 155         155        Tacna        Tacna        Tacna
# 156         156       Tumbes       Tumbes       Tumbes
#
#                          Entidad  \
# 0    Centro de Atención -  CLARO
# 1    Centro de Atención -  CLARO
# 2    Centro de Atención -  CLARO
# 3    Centro de Atención -  CLARO
# 4                      Plaza Vea
# ..                           ...
# 152  Centro de Atención -  CLARO
# ...
